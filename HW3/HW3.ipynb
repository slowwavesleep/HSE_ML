# %%
import numpy as np
import pandas as pd

import eli5

import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="text-align:justify">Возьмите четыре любые темы из корпуса 20newsgroups (постарайтесть брать не слишком похожие, и не слишком разные темы).</div>

# %%
subj = ['rec.sport.baseball', 'talk.politics.guns', 'talk.politics.misc', 'rec.autos']

# %%
news_train = fetch_20newsgroups(subset='train', categories=subj)

# %%
news_test = fetch_20newsgroups(subset='test', categories=subj)

# %%
# the order of the subjects is not kept
names = news_test.target_names
names
# Out:
# ['rec.autos', 'rec.sport.baseball', 'talk.politics.guns', 'talk.politics.misc']

# %%
y_train = news_train.target
y_test = news_test.target

# %%
X_train = news_train.data

# %%
X_test = news_test.data

# %% [markdown]
# <div style="text-align:justify">Векторизуйте датасет с помощью CountVectorizer.</div>

# %%
c_vect = CountVectorizer()

# %%
c_vect.fit(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
X_train_vec = c_vect.transform(X_train)

# %%
X_test_vec = c_vect.transform(X_test)

# %% [markdown]
# <div style="text-align:justify">
# Выберите три любых классификатора. <br>
# Используя кроссвалидацию (любой вариант из KFold, StratifiedKFold, RepeatedStratifiedKFold), подберите оптимальные параметры моделей с помощью grid_search. Обучите классификаторы с оптимальными параметрами.
# Оцените полученные классификаторы на тесте, мера качества - macro_f1.
# Посмотрите, насколько полученные результаты на тесте отличаются от результатов предсказания на трейне?<br>
# <strong>3 балла</strong>
# </div>

# %%
log_reg = LogisticRegression()
rf = RandomForestClassifier()
sgd = SGDClassifier()

# %%
def eval_model_gscv(model, X, y, gs_param_grid, folds=5, verbose=True):
    # utilizes StratifiedKFold by default for multiclass labels when `cv` is specified
    gridsearch = GridSearchCV(model, param_grid=gs_param_grid,
                             n_jobs=-1,  scoring='f1_macro', cv=folds).fit(X, y)
    
    if verbose:
        print(f'Best score: {gridsearch.best_score_}')
        print(f'Best parameters: {gridsearch.best_params_}')
        
    return gridsearch

# %%
def validate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    f = f1_score(y_test, y_pred, average='macro')
    print(f"Macro f-score on test data is {f:.5}")

# %%
# %%time

# only liblinear solver supports both l1 and l2 regularization
lr_gridsearch = eval_model_gscv(log_reg, X_train_vec, y_train,
                                gs_param_grid={'C': [1, 2, 3],
                                               'penalty':['l1', 'l2'],
                                               'intercept_scaling': [1, 2, 5],
                                               'solver': ['liblinear']})
# Out:
# Best score: 0.9544185713553807
# Best parameters: {'C': 2, 'intercept_scaling': 5, 'penalty': 'l2', 'solver': 'liblinear'}
# Wall time: 45.4 s

# %%
best_log_reg = LogisticRegression(**lr_gridsearch.best_params_)

# %%
print('Logistic regression')
validate_model(best_log_reg, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Logistic regression
# Macro f-score on test data is 0.86372

# %%
# %%time

rf_gridsearch = eval_model_gscv(rf, X_train_vec, y_train,
                               gs_param_grid={'n_estimators':[100, 150, 200],
                                              'max_depth': [10, 15, 20],
                                              'criterion':['gini', 'entropy']})
# Out:
# Best score: 0.9210640721979676
# Best parameters: {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 150}
# Wall time: 23.3 s

# %%
best_rf = RandomForestClassifier(**rf_gridsearch.best_params_)
print('Random forest')
validate_model(best_rf, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Random forest
# Macro f-score on test data is 0.85031

# %%
# %%time

sgd_gridsearch = eval_model_gscv(sgd, X_train_vec, y_train,
                                gs_param_grid={'penalty': ['l2', 'l1', 'elasticnet'],
                                               'loss': ['log', 'hinge', 'perceptron'],
                                               'alpha': [0.01, 0.001, 0.0001]})
# Out:
# Best score: 0.9528648261865843
# Best parameters: {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Wall time: 39.4 s

# %%
best_sgd = SGDClassifier(**sgd_gridsearch.best_params_)
print('SGD classifier')
validate_model(best_sgd, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# SGD classifier
# Macro f-score on test data is 0.85904

# %% [markdown]
# *В среднем результаты моделей на тесте хуже результатов на трейне примерно на 8-9 процентов, что довольно ощутимо.*

# %% [markdown]
# <div style="text-align:justify">
# Постройте функцию analyze_features(model, n), которая бы для каждой модели выводила самые значимые признаки по каждому из четырех классов.
# Для этого вам понадобится словарь, связывающий номер признака с самим признаком, он может быть таким:
# index_to_word = {v:k for k,v in count_vect.vocabulary_.items()}
# обращаться к весам модели можно либо через eli5, как мы делали на лекции, либо напрямую: через clf.coef_ - матрица размера (n_classes, n_features), то есть для получения признаков с наибольшим весом для класса n вам нужно сортировать веса внутри n-ной строки.
# Eсли вы используете деревья решений, то можно воспользоваться методом  model.feature_importances
# <br>
# <strong>4 балла</strong>
# </div>

# %%
index_to_word = {v:k for k, v in c_vect.vocabulary_.items()}

# %%
def get_word_by_index(feature):
    global index_to_word
    feature = int(feature.strip('x'))
    return index_to_word[feature]

# %%
def analyze_features(model, n):
    explanation = eli5.formatters.as_dataframe.explain_weights_df(model)
    if 'target' not in explanation.columns:
        explanation['word'] = explanation.feature.apply(get_word_by_index)
        explanation = explanation.nlargest(n, 'weight')
        explanation.drop('std', axis=1, inplace=True)
        explanation.reset_index(drop=True, inplace=True)
        return explanation
    target_feats = []
    for target in explanation.target.unique():
        subset = explanation.loc[explanation.target == target]
        subset = subset.nlargest(n, 'weight')
        subset = subset.loc[subset.feature != '<BIAS>']
        subset['word'] = subset.feature.apply(get_word_by_index)
        subset['subject'] = names[target]
        target_feats.append(subset)
    result = pd.concat(target_feats, axis=0)
    result.reset_index(drop=True, inplace=True)
    return result

# %% [markdown]
# <div style="text-align:justify">
# Примените функцию к вашим классификаторам, видны ли по отобранным словам очевидные ошибки?
# Используйте параметры CountVectorizer, для того, чтобы уменьшить количество признаков и убрать нерелевантные (например числа, токены слишком низкой или высокой документной частотой, и т.д.), постарайтесь добиться улучшения результатов работы моделей (снова выводите результаты модели на трейне и на тесте, чтобы видеть, уменьшается ли переобучение)
# <strong>3 балла </strong>
# </div>

# %%
analyze_features(best_log_reg, 10)
# Out:
#     target feature    weight        word             subject
# 0        0   x8549  1.783461         car           rec.autos
# 1        0   x8620  1.008140        cars           rec.autos
# 2        0  x33012  0.686610     warning           rec.autos
# 3        0  x14538  0.674743        ford           rec.autos
# 4        0  x32004  0.660695      unisql           rec.autos
# 5        0   x7416  0.642764         bmw           rec.autos
# 6        0  x21954  0.636252          my           rec.autos
# 7        0   x5797  0.607378         any           rec.autos
# 8        0  x12352  0.589280       drive           rec.autos
# 9        0   x6437  0.575745  automotive           rec.autos
# 10       1   x6774  1.633105    baseball  rec.sport.baseball
# 11       1  x24166  0.962798    phillies  rec.sport.baseball
# 12       1  x24408  0.869823     players  rec.sport.baseball
# 13       1  x30514  0.865217        team  rec.sport.baseball
# 14       1  x15000  0.854393        game  rec.sport.baseball
# 15       1  x10714  0.740533        cubs  rec.sport.baseball
# 16       1  x15002  0.718186       games  rec.sport.baseball
# 17       1  x33405  0.660682         win  rec.sport.baseball
# 18       1  x29455  0.653905       stats  rec.sport.baseball
# 19       1  x29034  0.583213         sox  rec.sport.baseball
# 20       2  x15787  1.260882         gun  talk.politics.guns
# 21       2  x15800  1.126646        guns  talk.politics.guns
# 22       2  x32909  0.937416        waco  talk.politics.guns
# 23       2  x13989  0.863423         fbi  talk.politics.guns
# 24       2   x6282  0.842719         atf  talk.politics.guns
# 25       2  x14257  0.683244    firearms  talk.politics.guns
# 26       2  x25810  0.628669       ranch  talk.politics.guns
# 27       2  x33123  0.621133     weapons  talk.politics.guns
# 28       2  x14121  0.618138     feustel  talk.politics.guns
# 29       2   x6813  0.602232        batf  talk.politics.guns
# 30       3   x9368  0.953829     clinton  talk.politics.misc
# 31       3  x22098  0.818658   narrative  talk.politics.misc
# 32       3  x18688  0.724176      kaldis  talk.politics.misc
# 33       3  x28128  0.707094      sexual  talk.politics.misc
# 34       3  x30479  0.702369         tax  talk.politics.misc
# 35       3  x15078  0.687871         gay  talk.politics.misc
# 36       3   x5065  0.597680     address  talk.politics.misc
# 37       3  x20174  0.589267        lynn  talk.politics.misc
# 38       3  x23180  0.549098    optilink  talk.politics.misc
# 39       3  x10737  0.549006      cunyvm  talk.politics.misc

# %%
analyze_features(best_sgd, 10)
# Out:
#     target feature    weight       word             subject
# 0        0   x8549  0.947075        car           rec.autos
# 1        0   x8620  0.577921       cars           rec.autos
# 2        0  x21954  0.348873         my           rec.autos
# 3        0  x13079  0.289875     engine           rec.autos
# 4        0  x25942  0.283385       read           rec.autos
# 5        0  x14538  0.278228       ford           rec.autos
# 6        0  x24942  0.256336      price           rec.autos
# 7        0  x33012  0.255041    warning           rec.autos
# 8        0   x5797  0.240954        any           rec.autos
# 9        0   x6416  0.239201       auto           rec.autos
# 10       1   x6774  0.807680   baseball  rec.sport.baseball
# 11       1      x0  0.600413         00  rec.sport.baseball
# 12       1  x30514  0.548758       team  rec.sport.baseball
# 13       1  x24408  0.477937    players  rec.sport.baseball
# 14       1  x15000  0.463068       game  rec.sport.baseball
# 15       1  x10714  0.396787       cubs  rec.sport.baseball
# 16       1  x16180  0.386546         he  rec.sport.baseball
# 17       1  x24166  0.365869   phillies  rec.sport.baseball
# 18       1  x27283  0.361296       runs  rec.sport.baseball
# 19       1  x15002  0.327756      games  rec.sport.baseball
# 20       2  x15787  0.896201        gun  talk.politics.guns
# 21       2  x14257  0.620852   firearms  talk.politics.guns
# 22       2  x15800  0.612216       guns  talk.politics.guns
# 23       2  x13989  0.518266        fbi  talk.politics.guns
# 24       2  x33123  0.482107    weapons  talk.politics.guns
# 25       2  x32909  0.450019       waco  talk.politics.guns
# 26       2   x6282  0.445099        atf  talk.politics.guns
# 27       2  x21189  0.402157    militia  talk.politics.guns
# 28       2  x14254  0.375569       fire  talk.politics.guns
# 29       2   x6813  0.340075       batf  talk.politics.guns
# 30       3  x30479  0.490845        tax  talk.politics.misc
# 31       3  x21958  0.464095      myers  talk.politics.misc
# 32       3  x21763  0.454774         ms  talk.politics.misc
# 33       3  x24887  0.412636  president  talk.politics.misc
# 34       3   x9368  0.398153    clinton  talk.politics.misc
# 35       3  x15078  0.395693        gay  talk.politics.misc
# 36       3  x18688  0.362996     kaldis  talk.politics.misc
# 37       3  x29012  0.354158      south  talk.politics.misc
# 38       3  x10550  0.350167      crime  talk.politics.misc
# 39       3  x12384  0.344266      drugs  talk.politics.misc

# %%
analyze_features(best_rf, 40)
# Out:
#    feature    weight        word
# 0    x8549  0.023245         car
# 1   x15787  0.017555         gun
# 2    x6774  0.013867    baseball
# 3   x15800  0.011954        guns
# 4    x8620  0.011412        cars
# 5   x32909  0.008754        waco
# 6   x30514  0.008656        team
# 7   x15000  0.008105        game
# 8   x33123  0.007521     weapons
# 9   x15002  0.007488       games
# 10  x19429  0.007276      league
# 11   x9368  0.006900     clinton
# 12  x23970  0.006830      people
# 13  x13079  0.006802      engine
# 14  x24408  0.005916     players
# 15  x27859  0.005499      season
# 16   x6813  0.005306        batf
# 17  x15468  0.005277  government
# 18  x13989  0.004615         fbi
# 19  x14254  0.004298        fire
# 20  x10189  0.004215     control
# 21  x30714  0.004201        that
# 22  x27283  0.004199        runs
# 23   x6059  0.004183        arms
# 24   x9309  0.004050     clayton
# 25  x24308  0.004036    pitching
# 26   x6282  0.003983         atf
# 27  x14257  0.003878    firearms
# 28  x31027  0.003871          to
# 29  x12352  0.003746       drive
# 30  x22659  0.003718         nra
# 31  x15988  0.003486     handgun
# 32  x22948  0.003412          of
# 33  x22592  0.003383         not
# 34  x19370  0.003353         law
# 35  x30134  0.003305   survivors
# 36  x33405  0.003265         win
# 37  x12721  0.003229         edu
# 38  x30518  0.003206       teams
# 39  x24166  0.003200    phillies

# %% [markdown]
# *В основном можно отметить стоп-слова как неправильные. Остальное – аббревиатуры и имена собственные, которые можно расценивать как разделяющие темы.*

# %%
c_vect = CountVectorizer(ngram_range=(1, 2), max_df=0.8, min_df=5, stop_words='english')

# %%
c_vect.fit(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.8, max_features=None, min_df=5,
#                 ngram_range=(1, 2), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
X_train_vec = c_vect.transform(X_train)

# %%
X_test_vec = c_vect.transform(X_test)

# %%
index_to_word = {v:k for k, v in c_vect.vocabulary_.items()}

# %%
# %%time

# only liblinear solver supports both l1 and l2 regularization
lr_gridsearch = eval_model_gscv(log_reg, X_train_vec, y_train,
                                gs_param_grid={'C': [1, 2, 3],
                                               'penalty':['l1', 'l2'],
                                               'intercept_scaling': [1, 2, 5],
                                               'solver': ['liblinear']})
# Out:
# Best score: 0.96054776592035
# Best parameters: {'C': 1, 'intercept_scaling': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# Wall time: 21.3 s

# %%
best_log_reg = LogisticRegression(**lr_gridsearch.best_params_)
print('Logistic regression')
validate_model(best_log_reg, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Logistic regression
# Macro f-score on test data is 0.86938

# %%
# %%time

rf_gridsearch = eval_model_gscv(rf, X_train_vec, y_train,
                               gs_param_grid={'n_estimators':[100, 150, 200],
                                              'max_depth': [10, 15, 20],
                                              'criterion':['gini', 'entropy']})
# Out:
# Best score: 0.9204860075161108
# Best parameters: {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200}
# Wall time: 12.9 s

# %%
best_rf = RandomForestClassifier(**rf_gridsearch.best_params_)
print('Random forest')
validate_model(best_rf, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Random forest
# Macro f-score on test data is 0.84276

# %%
# %%time

sgd_gridsearch = eval_model_gscv(sgd, X_train_vec, y_train,
                                gs_param_grid={'penalty': ['l2', 'l1', 'elasticnet'],
                                               'loss': ['log', 'hinge', 'perceptron'],
                                               'alpha': [0.01, 0.001, 0.0001]})
# Out:
# Best score: 0.961563613035959
# Best parameters: {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Wall time: 8.17 s

# %%
best_sgd = SGDClassifier(**sgd_gridsearch.best_params_)
print('SGD classifier')
validate_model(best_sgd, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# SGD classifier
# Macro f-score on test data is 0.87724

# %% [markdown]
# *Видим, что использование параметров CountVectorizer повысило результаты модели на тесте примерно на 1%. При этом разница между трейном и тестом по прежнему составляет порядка 8-9 процентов.*

# %%
analyze_features(best_log_reg, 10)
# Out:
#     target feature    weight          word             subject
# 0        0   x2771  1.542404           car           rec.autos
# 1        0   x2847  0.837227          cars           rec.autos
# 2        0   x6031  0.603442          ford           rec.autos
# 3        0   x2310  0.576001           bmw           rec.autos
# 4        0   x4920  0.547478         drive           rec.autos
# 5        0   x7669  0.517325    interested           rec.autos
# 6        0   x7113  0.496665         honda           rec.autos
# 7        0  x14570  0.479048        toyota           rec.autos
# 8        0  x15432  0.477540       warning           rec.autos
# 9        0  x15433  0.465963  warning read           rec.autos
# 10       1   x1974  1.377121      baseball  rec.sport.baseball
# 11       1  x10895  0.817339      phillies  rec.sport.baseball
# 12       1   x6215  0.809201          game  rec.sport.baseball
# 13       1  x14140  0.789623          team  rec.sport.baseball
# 14       1   x6221  0.681366         games  rec.sport.baseball
# 15       1   x4072  0.580858          cubs  rec.sport.baseball
# 16       1  x11017  0.579021       players  rec.sport.baseball
# 17       1  x13329  0.561110           sox  rec.sport.baseball
# 18       1  x15652  0.544638           win  rec.sport.baseball
# 19       1   x6336  0.520326        giants  rec.sport.baseball
# 20       2   x6700  1.019609          guns  talk.politics.guns
# 21       2   x6670  1.005298           gun  talk.politics.guns
# 22       2  x15347  0.717681          waco  talk.politics.guns
# 23       2   x1736  0.695861           atf  talk.politics.guns
# 24       2   x5781  0.692263           fbi  talk.politics.guns
# 25       2  x10085  0.570843           nra  talk.politics.guns
# 26       2   x5394  0.570214           eng  talk.politics.guns
# 27       2   x5926  0.553809      firearms  talk.politics.guns
# 28       2  x15521  0.493541       weapons  talk.politics.guns
# 29       2   x6782  0.475208       handgun  talk.politics.guns
# 30       3   x3243  0.802534       clinton  talk.politics.misc
# 31       3  x12921  0.711953        sexual  talk.politics.misc
# 32       3  x14117  0.547045           tax  talk.politics.misc
# 33       3   x6269  0.536407           gay  talk.politics.misc
# 34       3   x9035  0.526126  mail address  talk.politics.misc
# 35       3   x1148  0.511221       address  talk.politics.misc
# 36       3   x8096  0.506096        kaldis  talk.politics.misc
# 37       3   x6844  0.476697        harris  talk.politics.misc
# 38       3   x8307  0.434419            la  talk.politics.misc
# 39       3   x6664  0.426049        guilty  talk.politics.misc

# %%
analyze_features(best_sgd, 10)
# Out:
#     target feature    weight       word             subject
# 0        0   x2771  0.816749        car           rec.autos
# 1        0   x2847  0.484481       cars           rec.autos
# 2        0   x6031  0.298153       ford           rec.autos
# 3        0  x12064  0.255958   requests           rec.autos
# 4        0   x5400  0.253165     engine           rec.autos
# 5        0   x2310  0.242062        bmw           rec.autos
# 6        0  x12061  0.229471    request           rec.autos
# 7        0  x14570  0.227662     toyota           rec.autos
# 8        0  x10233  0.225937        oil           rec.autos
# 9        0   x4920  0.217415      drive           rec.autos
# 10       1   x1974  0.681766   baseball  rec.sport.baseball
# 11       1   x6215  0.428024       game  rec.sport.baseball
# 12       1  x14140  0.399839       team  rec.sport.baseball
# 13       1  x10895  0.331526   phillies  rec.sport.baseball
# 14       1   x6221  0.323717      games  rec.sport.baseball
# 15       1  x11017  0.296534    players  rec.sport.baseball
# 16       1  x12740  0.293589     season  rec.sport.baseball
# 17       1  x15942  0.262356       year  rec.sport.baseball
# 18       1  x15652  0.248741        win  rec.sport.baseball
# 19       1   x4072  0.234928       cubs  rec.sport.baseball
# 20       2   x6670  0.564202        gun  talk.politics.guns
# 21       2   x6700  0.508959       guns  talk.politics.guns
# 22       2  x15347  0.402391       waco  talk.politics.guns
# 23       2   x5781  0.398820        fbi  talk.politics.guns
# 24       2   x1736  0.355093        atf  talk.politics.guns
# 25       2   x9445  0.319506    militia  talk.politics.guns
# 26       2  x15521  0.291259    weapons  talk.politics.guns
# 27       2   x5926  0.289605   firearms  talk.politics.guns
# 28       2  x10085  0.272729        nra  talk.politics.guns
# 29       2   x5394  0.260561        eng  talk.politics.guns
# 30       3   x9729  0.569240      myers  talk.politics.misc
# 31       3   x9678  0.526152         ms  talk.politics.misc
# 32       3  x14117  0.328893        tax  talk.politics.misc
# 33       3  x13319  0.317495      south  talk.politics.misc
# 34       3  x12767  0.313577     secret  talk.politics.misc
# 35       3   x3243  0.301873    clinton  talk.politics.misc
# 36       3   x6269  0.261300        gay  talk.politics.misc
# 37       3  x11257  0.259198  president  talk.politics.misc
# 38       3   x8096  0.253699     kaldis  talk.politics.misc
# 39       3  x10995  0.251066       plan  talk.politics.misc

# %%
analyze_features(best_rf, 40)
# Out:
#    feature    weight          word
# 0    x2771  0.032033           car
# 1    x6700  0.021181          guns
# 2    x1974  0.019442      baseball
# 3    x6670  0.014696           gun
# 4   x14140  0.013792          team
# 5    x6516  0.013317    government
# 6    x2847  0.012164          cars
# 7   x11017  0.010804       players
# 8    x6221  0.010621         games
# 9   x15521  0.010146       weapons
# 10   x5400  0.009078        engine
# 11   x6215  0.008785          game
# 12   x3243  0.008607       clinton
# 13  x15347  0.008087          waco
# 14   x8442  0.007828        league
# 15   x5926  0.007334      firearms
# 16   x6676  0.006578   gun control
# 17  x10772  0.006494        people
# 18  x12740  0.006473        season
# 19  x10895  0.006115      phillies
# 20  x15652  0.005881           win
# 21   x5781  0.005831           fbi
# 22   x1596  0.005669          arms
# 23   x6269  0.005509           gay
# 24  x10957  0.005132      pitching
# 25   x2005  0.004939          batf
# 26  x13783  0.004846   subject gun
# 27   x3764  0.004791       control
# 28   x9374  0.004738          mets
# 29  x12453  0.004714          runs
# 30  x11083  0.004682     political
# 31  x10085  0.004404           nra
# 32  x12238  0.004256        rights
# 33  x14152  0.004253         teams
# 34   x1824  0.004154    automotive
# 35   x8404  0.004141           law
# 36   x1736  0.004127           atf
# 37   x6684  0.004113      gun like
# 38   x6031  0.003972          ford
# 39  x10333  0.003941  optilink com

# %% [markdown]
# *В целом фичи выглядят достаточно вменяемо. Например, для бейсбола наблюдаем счет игры (видимо) как фичу.*
