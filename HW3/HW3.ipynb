# %% [markdown]
# <div style="text-align:justify">Возьмите четыре любые темы из корпуса 20newsgroups (постарайтесть брать не слишком похожие, и не слишком разные темы).</div>

# %%
import numpy as np
import pandas as pd

import eli5

import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
subj = ['rec.sport.baseball', 'talk.politics.guns', 'talk.politics.misc', 'rec.autos']

# %%
news_train = fetch_20newsgroups(subset='train', categories=subj)

# %%
news_test = fetch_20newsgroups(subset='test', categories=subj)

# %%
# the order of the subjects is not kept
names = news_test.target_names
names
# Out:
# ['rec.autos', 'rec.sport.baseball', 'talk.politics.guns', 'talk.politics.misc']

# %%
y_train = news_train.target
y_test = news_test.target

# %%
X_train = news_train.data

# %%
X_test = news_test.data

# %% [markdown]
# <div style="text-align:justify">Векторизуйте датасет с помощью CountVectorizer.</div>

# %%
#убрать параметры
c_vect = CountVectorizer()

# %%
c_vect.fit(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
X_train_vec = c_vect.transform(X_train)

# %%
X_test_vec = c_vect.transform(X_test)

# %% [markdown]
# <div style="text-align:justify">
# Выберете три любых классификатора. <br>
# Используя кроссвалидацию (любой вариант из KFold, StratifiedKFold, RepeatedStratifiedKFold), подберите оптимальные параметры моделей с помощью grid_search. Обучите классификаторы с оптимальными параметрами.
# Оцените полученные классификаторы на тесте, мера качества - macro_f1.
# Посмотрите, насколько полученные результаты на тесте отличаются от результатов предсказания на трейне?<br>
# <strong>3 балла</strong>
# </div>

# %%
log_reg = LogisticRegression()
rf = RandomForestClassifier()
sgd = SGDClassifier()

# %%
def eval_model_gscv(model, X, y, gs_param_grid, folds=5, verbose=True):
    # utilizes StratifiedKFold by default for multiclass labels when `cv` is specified
    gridsearch = GridSearchCV(model, param_grid=gs_param_grid,
                             n_jobs=-1,  scoring='f1_macro', cv=folds).fit(X, y)
    
    if verbose:
        print(f'Best score: {gridsearch.best_score_}')
        print(f'Best parameters: {gridsearch.best_params_}')
        
    return gridsearch

# %%
def validate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    f = f1_score(y_test, y_pred, average='macro')
    print(f"Macro f-score on test data is {f:.5}")
    return model

# %%
# %%time

# only liblinear solver supports both l1 and l2 regularization
lr_gridsearch = eval_model_gscv(log_reg, X_train_vec, y_train,
                                gs_param_grid={'C': [1, 2, 3],
                                               'penalty':['l1', 'l2'],
                                               'intercept_scaling': [1, 2, 5],
                                               'solver': ['liblinear']})
# Out:
# Best score: 0.9544185713553807
# Best parameters: {'C': 2, 'intercept_scaling': 5, 'penalty': 'l2', 'solver': 'liblinear'}
# Wall time: 44.4 s

# %%
best_log_reg = LogisticRegression(**lr_gridsearch.best_params_)

# %%
print('Logistic regression')
validate_model(best_log_reg, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Logistic regression
# Macro f-score on test data is 0.86372
# LogisticRegression(C=2, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=5, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# %%time

rf_gridsearch = eval_model_gscv(rf, X_train_vec, y_train,
                               gs_param_grid={'n_estimators':[100, 150, 200],
                                              'max_depth': [10, 15, 20],
                                              'criterion':['gini', 'entropy']})
# Out:
# Best score: 0.9168589699200554
# Best parameters: {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200}
# Wall time: 23 s

# %%
best_rf = RandomForestClassifier(**rf_gridsearch.best_params_)
print('Random forest')
validate_model(best_rf, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Random forest
# Macro f-score on test data is 0.83895
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# %%time

sgd_gridsearch = eval_model_gscv(sgd, X_train_vec, y_train,
                                gs_param_grid={'penalty': ['l2', 'l1', 'elasticnet'],
                                               'loss': ['log', 'hinge', 'perceptron'],
                                               'alpha': [0.01, 0.001, 0.0001]})
# Out:
# Best score: 0.953519476767875
# Best parameters: {'alpha': 0.01, 'loss': 'hinge', 'penalty': 'l2'}
# Wall time: 36.9 s

# %%
best_sgd = SGDClassifier(**sgd_gridsearch.best_params_)
print('SGD classifier')
validate_model(best_sgd, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# SGD classifier
# Macro f-score on test data is 0.87526
# SGDClassifier(alpha=0.01, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# <div style="text-align:justify">
# Постройте функцию analyze_features(model, n), которая бы для каждой модели выводила самые значимые признаки по каждому из четырех классов.
# Для этого вам понадобится словарь, связывающий номер признака с самим признаком, он может быть таким:
# index_to_word = {v:k for k,v in count_vect.vocabulary_.items()}
# обращаться к весам модели можно либо через eli5, как мы делали на лекции, либо напрямую: через clf.coef_ - матрица размера (n_classes, n_features), то есть для получения признаков с наибольшим весом для класса n вам нужно сортировать веса внутри n-ной строки.
# Eсли вы используете деревья решений, то можно воспользоваться методом  model.feature_importances
# <br>
# <strong>4 балла</strong>
# <div>

# %%
index_to_word = {v:k for k, v in c_vect.vocabulary_.items()}

# %%
def get_word_by_index(feature, d=index_to_word):
    feature = int(feature.strip('x'))
    return d[feature]

# %%
def analyze_features(model, n):
    explanation = eli5.formatters.as_dataframe.explain_weights_df(model)
    if 'target' not in explanation.columns:
        explanation['word'] = explanation.feature.apply(get_word_by_index)
        explanation = explanation.nlargest(n, 'weight')
        explanation.drop('std', axis=1, inplace=True)
        return explanation
    target_feats = []
    for target in explanation.target.unique():
        subset = explanation.loc[explanation.target == target]
        subset = subset.nlargest(n, 'weight')
        subset = subset.loc[subset.feature != '<BIAS>']
        subset['word'] = subset.feature.apply(get_word_by_index)
        subset['subject'] = names[target]
        target_feats.append(subset)
    result = pd.concat(target_feats, axis=0)
    result.reset_index(drop=True, inplace=True)
    return result

# %% [markdown]
# <div style="text-align:justify">
# Примените функцию к вашим классификаторам, видны ли по отобранным словам очевидные ошибки?
# Используйте параметры CountVectorizer, для того, чтобы уменьшить количество признаков и убрать нерелевантные (например числа, токены слишком низкой или высокой документной частотой, и т.д.), постарайтесь добиться улучшения результатов работы моделей (снова выводите результаты модели на трейне и на тесте, чтобы видеть, уменьшается ли переобучение)
# <strong>3 балла </strong>

# %%
analyze_features(best_log_reg, 10)
# Out:
#     target feature    weight        word             subject
# 0        0   x8549  1.783461         car           rec.autos
# 1        0   x8620  1.008140        cars           rec.autos
# 2        0  x33012  0.686610     warning           rec.autos
# 3        0  x14538  0.674743        ford           rec.autos
# 4        0  x32004  0.660695      unisql           rec.autos
# 5        0   x7416  0.642764         bmw           rec.autos
# 6        0  x21954  0.636252          my           rec.autos
# 7        0   x5797  0.607378         any           rec.autos
# 8        0  x12352  0.589280       drive           rec.autos
# 9        0   x6437  0.575745  automotive           rec.autos
# 10       1   x6774  1.633105    baseball  rec.sport.baseball
# 11       1  x24166  0.962798    phillies  rec.sport.baseball
# 12       1  x24408  0.869823     players  rec.sport.baseball
# 13       1  x30514  0.865217        team  rec.sport.baseball
# 14       1  x15000  0.854393        game  rec.sport.baseball
# 15       1  x10714  0.740533        cubs  rec.sport.baseball
# 16       1  x15002  0.718186       games  rec.sport.baseball
# 17       1  x33405  0.660682         win  rec.sport.baseball
# 18       1  x29455  0.653905       stats  rec.sport.baseball
# 19       1  x29034  0.583213         sox  rec.sport.baseball
# 20       2  x15787  1.260882         gun  talk.politics.guns
# 21       2  x15800  1.126646        guns  talk.politics.guns
# 22       2  x32909  0.937416        waco  talk.politics.guns
# 23       2  x13989  0.863423         fbi  talk.politics.guns
# 24       2   x6282  0.842719         atf  talk.politics.guns
# 25       2  x14257  0.683244    firearms  talk.politics.guns
# 26       2  x25810  0.628669       ranch  talk.politics.guns
# 27       2  x33123  0.621133     weapons  talk.politics.guns
# 28       2  x14121  0.618138     feustel  talk.politics.guns
# 29       2   x6813  0.602232        batf  talk.politics.guns
# 30       3   x9368  0.953829     clinton  talk.politics.misc
# 31       3  x22098  0.818658   narrative  talk.politics.misc
# 32       3  x18688  0.724176      kaldis  talk.politics.misc
# 33       3  x28128  0.707094      sexual  talk.politics.misc
# 34       3  x30479  0.702369         tax  talk.politics.misc
# 35       3  x15078  0.687871         gay  talk.politics.misc
# 36       3   x5065  0.597680     address  talk.politics.misc
# 37       3  x20174  0.589267        lynn  talk.politics.misc
# 38       3  x23180  0.549098    optilink  talk.politics.misc
# 39       3  x10737  0.549006      cunyvm  talk.politics.misc

# %%
analyze_features(best_sgd, 10)
# Out:
#     target feature    weight       word             subject
# 0        0   x8549  0.621920        car           rec.autos
# 1        0   x8620  0.352332       cars           rec.autos
# 2        0  x33012  0.205527    warning           rec.autos
# 3        0  x21954  0.197520         my           rec.autos
# 4        0  x14538  0.197520       ford           rec.autos
# 5        0  x12352  0.192181      drive           rec.autos
# 6        0  x25942  0.189512       read           rec.autos
# 7        0   x5797  0.189512        any           rec.autos
# 8        0  x32004  0.186843     unisql           rec.autos
# 9        0  x24942  0.178835      price           rec.autos
# 10       1   x6774  0.492569   baseball  rec.sport.baseball
# 11       1      x0  0.330540         00  rec.sport.baseball
# 12       1  x30514  0.327299       team  rec.sport.baseball
# 13       1  x24408  0.311096    players  rec.sport.baseball
# 14       1  x15000  0.272209       game  rec.sport.baseball
# 15       1  x24166  0.265728   phillies  rec.sport.baseball
# 16       1  x10714  0.249525       cubs  rec.sport.baseball
# 17       1  x15002  0.239803      games  rec.sport.baseball
# 18       1  x33405  0.197676        win  rec.sport.baseball
# 19       1  x27859  0.197676     season  rec.sport.baseball
# 20       2  x15787  0.677543        gun  talk.politics.guns
# 21       2  x15800  0.502108       guns  talk.politics.guns
# 22       2  x13989  0.490009        fbi  talk.politics.guns
# 23       2  x14257  0.474885   firearms  talk.politics.guns
# 24       2  x14254  0.384143       fire  talk.politics.guns
# 25       2  x32909  0.359945       waco  talk.politics.guns
# 26       2   x6282  0.356920        atf  talk.politics.guns
# 27       2  x21189  0.314574    militia  talk.politics.guns
# 28       2  x33123  0.311549    weapons  talk.politics.guns
# 29       2  x33136  0.293400     weaver  talk.politics.guns
# 30       3  x21958  0.643741      myers  talk.politics.misc
# 31       3  x21763  0.640905         ms  talk.politics.misc
# 32       3  x24887  0.343140  president  talk.politics.misc
# 33       3  x15078  0.289258        gay  talk.politics.misc
# 34       3   x9368  0.277915    clinton  talk.politics.misc
# 35       3  x30479  0.269407        tax  talk.politics.misc
# 36       3  x18688  0.246720     kaldis  talk.politics.misc
# 37       3  x10550  0.246720      crime  talk.politics.misc
# 38       3  x28128  0.238213     sexual  talk.politics.misc
# 39       3  x33299  0.238213      white  talk.politics.misc

# %%
analyze_features(best_rf, 40)
# Out:
#    feature    weight        word
# 0    x8549  0.027019         car
# 1   x15787  0.017260         gun
# 2    x8620  0.012959        cars
# 3    x6774  0.011931    baseball
# 4   x15468  0.009113  government
# 5   x15800  0.007311        guns
# 6   x30514  0.007266        team
# 7    x6059  0.007091        arms
# 8   x32909  0.006592        waco
# 9    x9368  0.006436     clinton
# 10  x15000  0.006025        game
# 11  x33123  0.005940     weapons
# 12  x15002  0.005757       games
# 13  x24408  0.005662     players
# 14  x14257  0.005605    firearms
# 15  x19429  0.005403      league
# 16  x27283  0.005102        runs
# 17  x23970  0.004832      people
# 18  x26890  0.004805      rights
# 19  x16180  0.004723          he
# 20  x15078  0.004470         gay
# 21  x13989  0.004423         fbi
# 22  x22592  0.004391         not
# 23  x22948  0.004389          of
# 24  x14254  0.004297        fire
# 25  x30714  0.004218        that
# 26  x13079  0.004101      engine
# 27  x24308  0.004100    pitching
# 28  x31027  0.003926          to
# 29  x27859  0.003894      season
# 30  x30518  0.003870       teams
# 31  x10484  0.003796      cramer
# 32   x6813  0.003742        batf
# 33   x6282  0.003713         atf
# 34  x18066  0.003689          it
# 35  x15988  0.003510     handgun
# 36  x33108  0.003453          we
# 37  x34026  0.003373         you
# 38  x10189  0.003315     control
# 39  x33405  0.003233         win

# %% [markdown]
# В основном можно отметь стоп-слова как неправильные. Остальное – аббревиатуры и имена собствнные, которые можно расценивать, как разделяющие темы.

# %%
c_vect = CountVectorizer(ngram_range=(1, 2), max_df=0.9, min_df=3, stop_words='english')

# %%
c_vect.fit(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.9, max_features=None, min_df=3,
#                 ngram_range=(1, 2), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
X_train_vec = c_vect.transform(X_train)

# %%
X_test_vec = c_vect.transform(X_test)

# %%
index_to_word = {v:k for k, v in c_vect.vocabulary_.items()}

# %%
# %%time

# only liblinear solver supports both l1 and l2 regularization
lr_gridsearch = eval_model_gscv(log_reg, X_train_vec, y_train,
                                gs_param_grid={'C': [1, 2, 3],
                                               'penalty':['l1', 'l2'],
                                               'intercept_scaling': [1, 2, 5],
                                               'solver': ['liblinear']})
# Out:
# Best score: 0.9616504581066844
# Best parameters: {'C': 1, 'intercept_scaling': 2, 'penalty': 'l2', 'solver': 'liblinear'}
# Wall time: 30.3 s

# %%
best_log_reg = LogisticRegression(**lr_gridsearch.best_params_)
print('Logistic regression')
validate_model(best_log_reg, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Logistic regression
# Macro f-score on test data is 0.87104
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=2, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# %%time

rf_gridsearch = eval_model_gscv(rf, X_train_vec, y_train,
                               gs_param_grid={'n_estimators':[100, 150, 200],
                                              'max_depth': [10, 15, 20],
                                              'criterion':['gini', 'entropy']})
# Out:
# Best score: 0.9167424532722646
# Best parameters: {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 200}
# Wall time: 16.6 s

# %%
best_rf = RandomForestClassifier(**rf_gridsearch.best_params_)
print('Random forest')
validate_model(best_rf, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# Random forest
# Macro f-score on test data is 0.84408
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# %%time

sgd_gridsearch = eval_model_gscv(sgd, X_train_vec, y_train,
                                gs_param_grid={'penalty': ['l2', 'l1', 'elasticnet'],
                                               'loss': ['log', 'hinge', 'perceptron'],
                                               'alpha': [0.01, 0.001, 0.0001]})
# Out:
# Best score: 0.962212443505928
# Best parameters: {'alpha': 0.01, 'loss': 'hinge', 'penalty': 'l2'}
# Wall time: 11 s

# %%
best_sgd = SGDClassifier(**sgd_gridsearch.best_params_)
print('SGD classifier')
validate_model(best_sgd, X_train_vec, y_train, X_test_vec, y_test)
# Out:
# SGD classifier
# Macro f-score on test data is 0.87768
# SGDClassifier(alpha=0.01, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# Видим, что использование параметров CountVectorizer повысили результаты модели на тесте примерно на 1%.

# %%
analyze_features(best_log_reg, 10)
# Out:
#     target feature    weight           word             subject
# 0        0   x6196  1.500435    assenmacher           rec.autos
# 1        0   x6381  0.818883            aug           rec.autos
# 2        0  x12974  0.540159         empire           rec.autos
# 3        0   x5224  0.529866    affiliation           rec.autos
# 4        0  x10663  0.502515            csc           rec.autos
# 5        0  x16543  0.476275          hoffs           rec.autos
# 6        0  x31311  0.463805    transporter           rec.autos
# 7        0  x15403  0.461948          goncz           rec.autos
# 8        0  x33137  0.437863         webber           rec.autos
# 9        0  x29743  0.427708         strong           rec.autos
# 10       1   x4506  1.312562           _can  rec.sport.baseball
# 11       1  x13381  0.791507            eu8  rec.sport.baseball
# 12       1  x30353  0.779465            tag  rec.sport.baseball
# 13       1  x23390  0.772337          ovens  rec.sport.baseball
# 14       1  x13406  0.610197     evaluators  rec.sport.baseball
# 15       1  x28611  0.562637       skorpion  rec.sport.baseball
# 16       1  x23671  0.559735          paras  rec.sport.baseball
# 17       1  x33586  0.540803       workable  rec.sport.baseball
# 18       1   x8904  0.518893    challenging  rec.sport.baseball
# 19       1  x34235  0.510579            zss  rec.sport.baseball
# 20       2  x14476  0.987939       foghorns  talk.politics.guns
# 21       2  x14413  0.966960        flowery  talk.politics.guns
# 22       2  x32948  0.676386        walkout  talk.politics.guns
# 23       2  x12434  0.666610           duck  talk.politics.guns
# 24       2   x4003  0.664289             87  talk.politics.guns
# 25       2  x12735  0.533158          eecae  talk.politics.guns
# 26       2  x21758  0.496697            mrs  talk.politics.guns
# 27       2  x33318  0.486716           whiz  talk.politics.guns
# 28       2  x14667  0.474738     framingham  talk.politics.guns
# 29       2   x6499  0.434169         awca89  talk.politics.guns
# 30       3   x7237  0.791746     bipartisan  talk.politics.misc
# 31       3  x27753  0.549618      scientist  talk.politics.misc
# 32       3  x30307  0.548988             t3  talk.politics.misc
# 33       3  x13514  0.527741    excercising  talk.politics.misc
# 34       3  x17392  0.499473   inconsistent  talk.politics.misc
# 35       3   x2750  0.492170            435  talk.politics.misc
# 36       3  x14803  0.470229             fu  talk.politics.misc
# 37       3  x19488  0.461940     legalistic  talk.politics.misc
# 38       3  x19397  0.456185        lazarus  talk.politics.misc
# 39       3   x5103  0.452683  adminstration  talk.politics.misc

# %%
analyze_features(best_sgd, 10)
# Out:
#     target feature    weight            word             subject
# 0        0   x6196  0.381118     assenmacher           rec.autos
# 1        0   x6381  0.211732             aug           rec.autos
# 2        0   x5224  0.175435     affiliation           rec.autos
# 3        0  x15403  0.154262           goncz           rec.autos
# 4        0  x16543  0.154262           hoffs           rec.autos
# 5        0  x10663  0.154262             csc           rec.autos
# 6        0  x12974  0.148213          empire           rec.autos
# 7        0  x31311  0.139138     transporter           rec.autos
# 8        0  x24440  0.136114            plow           rec.autos
# 9        0  x29743  0.133089          strong           rec.autos
# 10       1   x4506  0.383464            _can  rec.sport.baseball
# 11       1  x30353  0.263889             tag  rec.sport.baseball
# 12       1  x23390  0.243273           ovens  rec.sport.baseball
# 13       1  x13381  0.218533             eu8  rec.sport.baseball
# 14       1  x13406  0.193793      evaluators  rec.sport.baseball
# 15       1  x28611  0.169054        skorpion  rec.sport.baseball
# 16       1   x8904  0.164931     challenging  rec.sport.baseball
# 17       1  x11767  0.160807  directionality  rec.sport.baseball
# 18       1  x33586  0.152561        workable  rec.sport.baseball
# 19       1  x27384  0.152561              s5  rec.sport.baseball
# 20       2  x14476  0.281301        foghorns  talk.politics.guns
# 21       2  x14413  0.248029         flowery  talk.politics.guns
# 22       2   x4003  0.199633              87  talk.politics.guns
# 23       2  x12735  0.196609           eecae  talk.politics.guns
# 24       2  x12434  0.196609            duck  talk.politics.guns
# 25       2  x32948  0.184510         walkout  talk.politics.guns
# 26       2  x14667  0.169386      framingham  talk.politics.guns
# 27       2  x33318  0.151237            whiz  talk.politics.guns
# 28       2  x21758  0.148213             mrs  talk.politics.guns
# 29       2  x14679  0.148213          franco  talk.politics.guns
# 30       3   x7237  0.193584      bipartisan  talk.politics.misc
# 31       3  x27448  0.193584          saddam  talk.politics.misc
# 32       3  x28589  0.190559           skill  talk.politics.misc
# 33       3  x30307  0.166361              t3  talk.politics.misc
# 34       3  x14803  0.157287              fu  talk.politics.misc
# 35       3  x27753  0.154262       scientist  talk.politics.misc
# 36       3  x13514  0.145188     excercising  talk.politics.misc
# 37       3  x33116  0.133089          weakly  talk.politics.misc
# 38       3  x23608  0.133089        pamuelle  talk.politics.misc
# 39       3   x2750  0.130064             435  talk.politics.misc

# %%
analyze_features(best_rf, 40)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-dab185595285> in <module>
# ----> 1 analyze_features(best_rf, 40)
#
# <ipython-input-25-044b641c8435> in analyze_features(model, n)
#       2     explanation = eli5.formatters.as_dataframe.explain_weights_df(model)
#       3     if 'target' not in explanation.columns:
# ----> 4         explanation['word'] = explanation.feature.apply(get_word_by_index)
#       5         explanation = explanation.nlargest(n, 'weight')
#       6         explanation.drop('std', axis=1, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-bd68cd926e2e> in get_word_by_index(feature, d)
#       1 def get_word_by_index(feature, d=index_to_word):
#       2     feature = int(feature.strip('x'))
# ----> 3     return d[feature]
#
# KeyError: 34355

# %%
index_to_word[34355]
# Out:
# 'yesterday'
